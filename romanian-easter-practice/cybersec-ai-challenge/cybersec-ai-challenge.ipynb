# %% [markdown]
# # Cram School Easter Round: Cybersecurity AI Challenge

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from datetime import time
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score

# %% [markdown]
# ## Load the data

# %%
df_train = pd.read_csv("./train_data.csv", parse_dates=["Timestamp"])
df_test = pd.read_csv("./test_data.csv", parse_dates=["Timestamp"])

# %%
df_train.isna().any()
# Out:
# ID                          False
# Timestamp                   False
# Suspicious_Port_Activity    False
# Traffic_Volume_Variation    False
# Packet_Length_Anomaly       False
# Malware_Score               False
# Threat_Level_Index          False
# User_Behavior_Score          True
# Geo_Dispersion              False
# Payload_Entropy             False
# Login_Attempts              False
# Device_Response_Time        False
# Session_Duration            False
# Packet_Retry_Rate           False
# Anomaly_Tendency            False
# Attack Type                 False
# dtype: bool

# %%
df_test.isna().any()
# Out:
# ID                          False
# Timestamp                   False
# Suspicious_Port_Activity    False
# Traffic_Volume_Variation    False
# Packet_Length_Anomaly       False
# Malware_Score               False
# Threat_Level_Index          False
# User_Behavior_Score          True
# Geo_Dispersion              False
# Payload_Entropy             False
# Login_Attempts              False
# Device_Response_Time        False
# Session_Duration            False
# Packet_Retry_Rate           False
# Anomaly_Tendency            False
# dtype: bool

# %%
df_train.fillna({'User_Behavior_Score': df_train['User_Behavior_Score'].mean()}, inplace=True)
df_test.fillna({'User_Behavior_Score': df_test['User_Behavior_Score'].mean()}, inplace=True)

# %%
df_train.describe()
# Out:
#                  ID                      Timestamp  Suspicious_Port_Activity  \
# count  13356.000000                          13356              13356.000000
# mean   19904.823600  2023-01-28 19:12:46.451033344                 49.791904
# min        7.000000            2023-01-01 00:00:00                  9.830626
# 25%     9985.750000            2023-01-15 00:00:15                 43.117314
# 50%    19880.500000            2023-01-28 17:56:30                 49.912484
# 75%    29923.500000            2023-02-11 16:48:15                 56.573445
# max    39996.000000            2023-02-25 13:10:00                 97.241773
# std    11550.807566                            NaN                 10.075306
#
#        Traffic_Volume_Variation  Packet_Length_Anomaly  Malware_Score  \
# count              13356.000000           13356.000000   13356.000000
# mean                  49.788837              49.807553       7.223436
# min                   11.447170               9.704399     -40.898692
# 25%                   43.043988              42.978653      -2.796696
# 50%                   49.946217              49.918006       6.839157
# 75%                   56.550146              56.620733      16.848907
# max                   97.398056              98.353307      63.855348
# std                   10.080638              10.209363      14.450361
#
#        Threat_Level_Index  User_Behavior_Score  Geo_Dispersion  \
# count        13356.000000         13356.000000    13356.000000
# mean             4.070842            -0.001211       50.172048
# min            -20.865728            -4.207929        0.002713
# 25%             -0.800068            -0.597838       25.838683
# 50%              3.734464            -0.001211       50.284962
# 75%              8.794495             0.592959       74.787214
# max             27.272845             4.185208       99.989204
# std              6.802323             0.958667       28.621882
#
#        Payload_Entropy  Login_Attempts  Device_Response_Time  \
# count     13356.000000    1.335600e+04          1.335600e+04
# mean         11.148770    1.407737e+05          4.828117e+06
# min        -102.528539   -8.428669e+08          0.000000e+00
# 25%          -9.625675    3.686437e+00          0.000000e+00
# 50%          11.211696    1.449021e+03          0.000000e+00
# 75%          31.656160    2.913327e+05          7.785192e+06
# max         138.235090    8.818372e+08          3.999218e+07
# std          30.631642    8.748305e+07          7.278543e+06
#
#        Session_Duration  Packet_Retry_Rate  Anomaly_Tendency   Attack Type
# count      13356.000000       13356.000000      13356.000000  13356.000000
# mean          15.143093          19.936004          1.604717      0.745283
# min          -35.197389          -6.683795        -73.746635      0.000000
# 25%            5.967130          15.665370         -8.751905      0.000000
# 50%           15.215888          19.921653          1.568656      0.000000
# 75%           24.254570          24.321041         11.893369      1.000000
# max           65.088692          44.933708         58.459195      2.000000
# std           13.130384           6.446938         15.255836      0.827976

# %%
df_test.describe()
# Out:
#                  ID                      Timestamp  Suspicious_Port_Activity  \
# count   7500.000000                           7500               7500.000000
# mean   19848.977333  2023-01-28 11:51:49.119999744                 50.138610
# min        0.000000            2023-01-01 00:07:00                 12.056187
# 25%     9770.750000            2023-01-14 20:59:30                 43.056456
# 50%    19922.500000            2023-01-28 00:49:00                 50.140781
# 75%    29615.500000            2023-02-11 07:01:15                 57.044083
# max    39997.000000            2023-02-25 13:16:00                 86.440026
# std    11560.133150                            NaN                 10.305109
#
#        Traffic_Volume_Variation  Packet_Length_Anomaly  Malware_Score  \
# count               7500.000000            7500.000000    7500.000000
# mean                  50.120978              50.155341       9.905555
# min                   11.257373              12.671509     -40.898692
# 25%                   43.248044              42.988945      -0.087082
# 50%                   50.179219              50.268250       9.863080
# 75%                   57.119216              57.197588      19.833414
# max                   86.422501              86.579586      75.400715
# std                   10.305518              10.412693      14.444796
#
#        Threat_Level_Index  User_Behavior_Score  Geo_Dispersion  \
# count         7500.000000          7500.000000     7500.000000
# mean             5.377551             0.011313       50.118944
# min            -16.382542            -3.403769        0.021645
# 25%              0.609952            -0.566398       26.149742
# 50%              5.315728             0.011313       50.032403
# 75%             10.372933             0.594068       74.732869
# max             27.815069             3.780323       99.941817
# std              6.827700             0.937631       28.590484
#
#        Payload_Entropy  Login_Attempts  Device_Response_Time  \
# count      7500.000000    7.500000e+03          7.500000e+03
# mean         11.010308    2.365471e+06          6.563752e+06
# min        -102.528539   -1.116288e+09          0.000000e+00
# 25%          -9.103703   -1.287796e+07          0.000000e+00
# 50%          11.404631    1.517705e+03          4.033571e+06
# 75%          31.328711    1.721521e+07          1.057671e+07
# max         123.655156    9.003638e+08          3.823556e+07
# std          30.136054    1.013622e+08          7.755322e+06
#
#        Session_Duration  Packet_Retry_Rate  Anomaly_Tendency
# count       7500.000000        7500.000000       7500.000000
# mean          15.135375          20.048670          1.918573
# min          -30.442588          -3.958067        -53.664412
# 25%            5.797551          15.706623         -8.433390
# 50%           15.073778          20.029074          1.778833
# 75%           24.415288          24.510951         12.137416
# max           69.376365          41.173987         58.960541
# std           13.233457           6.479375         15.491881

# %% [markdown]
# ## Subtask 1

# %%
value_subtask1 = (df_test["Timestamp"].dt.time < time(12, 0, 0)).map({True: "AM", False: "PM"}).to_list()
value_subtask1[:5]  # first 5
# Out:
# ['PM', 'PM', 'AM', 'AM', 'AM']

# %%
task1 = pd.DataFrame({
    'subtaskID': 1,
    'datapointID': df_test.ID,
    'answer':  value_subtask1
})

# %% [markdown]
# ## Subtask 2

# %%
X = df_train.drop(columns=["Attack Type", "ID", "Timestamp"]).to_numpy()
y = df_train["Attack Type"].to_numpy()

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
clf = RandomForestClassifier(random_state=42)

# %%
for fold, (train_idx, val_idx) in enumerate(kf.split(X, y), 1):
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_val)
    acc = f1_score(y_val, y_pred, average="macro")
    print(f"Fold {fold} F1 score: {acc}")
# Out:
# Fold 1 F1 score: 0.8625513527224303
# Fold 2 F1 score: 0.8625469946097749
# Fold 3 F1 score: 0.8674975074775673
# Fold 4 F1 score: 0.862116676978863
# Fold 5 F1 score: 0.8620215125612661

# %%
X_test = df_test.drop(columns=["ID", "Timestamp"]).to_numpy()

# %%
y_pred = clf.predict(X_test).tolist()
y_pred[: 5]  # first 5
# Out:
# [1, 2, 1, 1, 2]

# %%
task2 = pd.DataFrame({
    'subtaskID': 2,
    'datapointID': df_test.ID,
    'answer': y_pred
})

# %% [markdown]
# ## Save answers

# %%
submission_df = pd.concat([task1, task2], ignore_index=True)
submission_df.to_csv("submission.csv", index=False)

# %% [markdown]
# ## Submission results
#
# Subtask 1:
# - Accuracy: 1
# - Score: 20/20
#
# Subtask 2:
# - F1 score: 0.8931
# - Score: 80/80
