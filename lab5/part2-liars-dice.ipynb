# %% [markdown]
# # Lab 5 Part 2 - Liar's Dice

# %% [markdown]
# In Part 1, you are introduced to orchestrating LLM calls using Langchain. In Part 2, we will use that knowledge to pit LLMs against each other to play a full game of Liar's Dice.

# %% [markdown]
# This video succintly explains Liar's Dice: https://www.youtube.com/watch?v=fAbnMuiR734.

# %% [markdown]
# Before we go any further, I will first show you a game transcript using the sample solution.

# %% [markdown]
# ## Sample transcript

# %% [markdown]
# ```
# LIAR'S DICE!
# Players: Alice, Bob
# Total dice: 6
#
# DICE (visible for demo):
# Alice: [5, 4, 1]
# Bob: [6, 4, 1]
#
#                        --- TURN 1 ---
#
# ============================================================
# ROUND 1 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [5, 4, 1] (3 dice) ← CURRENT TURN
#    Bob: [6, 4, 1] (3 dice)
#
# CURRENT BID: None (round start)
#
# 📊 TOTAL DICE IN PLAY: 6
#
# Alice's turn
#
# 🤔 Alice is thinking...
# 💭 Alice's thoughts:
#    Okay, let's analyze this Liar's Dice situation. I have [5, 4, 1]. The game has just started, so I'm the first bidder. There are a total of 6 dice in play.
#
# 1. My hand: I have a 5, a 4, and a 1. The 1 is wild. That means I have at least one "5" and one "4" (or a 1 acting as either). I have no other matching dice besides the 1.
#
# 2. Opponent inference: Since it's the first bid, I have no information about my opponents' dice.
#
# 3. Mathematical odds: I can't calculate odds without a bid. However, I know the distribution of dice is essentially random at the start. With 6 dice, the expected number of any specific face (including 1s) is around 1.0. I have a 1, so I have a better than average chance of seeing 1's in the total.
#
# 4. Bid or challenge: Since I'm the first bidder, I can't challenge. I must bid.
#
# 5. Strategic bid: Given my hand, I want to start with a bid that is low, but not too low. I'll use the 1 as a "5" for the bid. I could bid "one 5". However, I have a 5 and a 1 so the odds of there being more than that is pretty decent. I'm going to bid "two 5s". This is a reasonable starting point that hopefully gives me a chance to get some information.
#
# 🤖 Alice decides: BID 2 5
# ✅ Alice bids 2 dice show 5
#
#                        --- TURN 2 ---
#
# ============================================================
# ROUND 1 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [5, 4, 1] (3 dice)
#    Bob: [6, 4, 1] (3 dice) ← CURRENT TURN
#
# CURRENT BID: 2 dice show 5 (by Alice)
#
# 📊 TOTAL DICE IN PLAY: 6
#
# 📜 RECENT HISTORY:
#    • Alice bids 2 dice show 5
#
# Bob's turn
#
# 🤔 Bob is thinking...
# 💭 Bob's thoughts:
#    Okay, let's analyze this Liar's Dice situation.
#
# 1. My hand: I have a 6, a 4, and a 1. The 1 is a wild, so I essentially have two dice that don't help me with the current bid of "2 dice showing 5".
#
# 2. Opponent's bidding pattern: Alice bid "2 dice show 5". Since I don't know anything else, it doesn't tell me anything about her hand. She could have a 5 and a wild, or she could be bluffing.
#
# 3. Mathematical odds: There are 6 dice in total. The bid is 2 dice showing 5. To calculate the probability, we need to consider the odds of rolling 5s on 6 dice.
#
# *   **Zero 5s:** (4/6)^6
# *   **One 5:** 6 * (1/6) * (4/6)^5
# *   **Two 5s:** 15 * (1/6)^2 * (4/6)^4
#
# If we use the 1s as wilds, the probabilities are a bit harder, but the chance of there being two 5s or more is pretty high.
#
# 4. Should I bid higher or challenge? Given my hand, I can't really *help* the bid, and the odds might favor me. I think I should challenge.
#
# 5. Strategic considerations: A challenge now is the best course of action. I have a very bad hand for this bid, and I don't want to start bidding on something I don't have a good chance of getting.
#
# 🤖 Bob decides: CHALLENGE
#
#                   🚨 CHALLENGE RESOLUTION 🚨
# Bob challenges Alice's bid:
# BID: 2 dice show 5
#
# COUNTING DICE SHOWING 5:
#    Alice: 1 natural 5s + 1 wilds = 2 total
#    Bob: 0 natural 5s + 1 wilds = 1 total
#
# FINAL COUNT: 3 dice show 5
# BID CLAIMED: 2 dice show 5
# ✅ BID WAS TRUE! Bob loses a die!
# Alice wins the challenge!
# Bob now has 2 dice
#
# Rolling new dice for next round...
#    Alice: [6, 5, 4]
#    Bob: [2, 6]
#
# NEW ROUND 2! Alice starts with fresh dice
#
#                        --- TURN 3 ---
#
# ============================================================
# ROUND 2 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [6, 5, 4] (3 dice) ← CURRENT TURN
#    Bob: [2, 6] (2 dice)
#
# CURRENT BID: None (round start)
#
# 📊 TOTAL DICE IN PLAY: 5
#
# 📜 RECENT HISTORY:
#    • Alice bids 2 dice show 5
#    • Bob challenges Alice's bid
#    • Challenge: Bob vs Alice - Alice wins
#
# Alice's turn
#
# 🤔 Alice is thinking...
# 💭 Alice's thoughts:
#    Okay, let's analyze this Liar's Dice situation.
#
# First, let's recall the game history: I lost the last round because I bid 2 fives, and Bob challenged. It appears Bob is challenging frequently or he has a good hand.
#
# Now, let's assess my hand: [6, 5, 4]. I have one five.
#
# The current bid is: None. It is my turn to bid and I start.
#
# I know the total number of dice is 5. The previous bid was 2 fives by me, which got challenged and was successful.
#
# Considering my hand, I have one five. With the total dice count at 5, the minimum bid I should consider is 1 five. If I include the possibility that my other opponent also has a five, I can consider 2 fives.
#
# I will start by bidding 1 five.
#
# My bid: 1 die show 5.
#
# 🤖 Alice decides: BID 1 5
# ✅ Alice bids 1 dice show 5
#
#                        --- TURN 4 ---
#
# ============================================================
# ROUND 2 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [6, 5, 4] (3 dice)
#    Bob: [2, 6] (2 dice) ← CURRENT TURN
#
# CURRENT BID: 1 dice show 5 (by Alice)
#
# 📊 TOTAL DICE IN PLAY: 5
#
# 📜 RECENT HISTORY:
#    • Alice bids 2 dice show 5
#    • Bob challenges Alice's bid
#    • Challenge: Bob vs Alice - Alice wins
#    • Alice bids 1 dice show 5
#
# Bob's turn
#
# 🤔 Bob is thinking...
# 💭 Bob's thoughts:
#    Okay, let's analyze this Liar's Dice situation.
#
# 1. My hand: I have a 2 and a 6. The current bid is 1 die showing a 5. I have no 5s, and only two dice. This makes it slightly more likely the bid is false.
#
# 2. Opponent inference: Alice bid 2 fives, and won the challenge. Then she bid 1 five. This suggests she is confident about having 5s, or is trying to bluff. The first bid was higher than the current, so she could have had more 5s. She probably has at least one die that shows a 5.
#
# 3. Mathematical odds: There are 5 dice total. The bid is for one 5. Considering 1s are wild, the bid is a 1/6 chance of being true on any given die, plus the wild, which makes it likely. Alice has a die, so it could be true. Without the wild, the chance is 1 - (5/6)^5 = 0.598. With a wild, it increases significantly, but is still less than 1. Because the previous bid was for two 5s, and the current bid is for one, I need to be careful.
#
# 4. Bid or Challenge? Given the opponent's bidding pattern, and the possible probabilities, I think it is best to challenge. If I bid, I might be forced to bid even higher, which is less likely given the low chance of the bid being true. Challenging is the better move this round.
#
# 5. No bid.
#
# 🤖 Bob decides: CHALLENGE
#
#                   🚨 CHALLENGE RESOLUTION 🚨
# Bob challenges Alice's bid:
# BID: 1 dice show 5
#
# COUNTING DICE SHOWING 5:
#    Alice: 1 natural 5s + 0 wilds = 1 total
#    Bob: 0 natural 5s + 0 wilds = 0 total
#
# FINAL COUNT: 1 dice show 5
# BID CLAIMED: 1 dice show 5
# ✅ BID WAS TRUE! Bob loses a die!
# Alice wins the challenge!
# Bob now has 1 dice
#
# Rolling new dice for next round...
#    Alice: [2, 5, 2]
#    Bob: [3]
#
# NEW ROUND 3! Alice starts with fresh dice
#
#                        --- TURN 5 ---
#
# ============================================================
# ROUND 3 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [2, 5, 2] (3 dice) ← CURRENT TURN
#    Bob: [3] (1 dice)
#
# CURRENT BID: None (round start)
#
# 📊 TOTAL DICE IN PLAY: 4
#
# 📜 RECENT HISTORY:
#    • Bob challenges Alice's bid
#    • Challenge: Bob vs Alice - Alice wins
#    • Alice bids 1 dice show 5
#    • Bob challenges Alice's bid
#    • Challenge: Bob vs Alice - Alice wins
#
# Alice's turn
#
# 🤔 Alice is thinking...
# 💭 Alice's thoughts:
#    Okay, let's analyze this Liar's Dice situation.
#
# My dice: [2, 5, 2]
# Total dice: 4
# Current bid: None
# Game History: Alice wins the previous two challenges.
#
# 1. My hand: I have two 2s and one 5. This gives me a decent starting hand. The fact that I have only three dice in play means I want to be conservative with my bids.
#
# 2. Opponent's inference: Bob has challenged twice and lost twice. This means Bob either thinks my bids are lies, or is just bad at estimating.
#
# 3. Mathematical odds: I need to consider the previous bids. I won the last two challenges. Now I need to determine the best bid.
#
# 4. Should I bid or challenge? Since I start the round I need to bid. I have to determine a good bid.
#
# 5. Strategic bid: I know there are only 4 dice in the game. Since I have two 2s, I could bid:
# * "2 dice show 2"
# * "2 dice show 5"
# * "3 dice show 2"
# * "1 dice show 5"
# * "1 dice show 1" (Wild)
#
# Given the history, I should bid lower. My strategy is to bid "1 dice show 5". This is a safe bid. It is possible based on my hand and the game history.
#
# 🤖 Alice decides: BID 1 5
# ✅ Alice bids 1 dice show 5
#
#                        --- TURN 6 ---
#
# ============================================================
# ROUND 3 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [2, 5, 2] (3 dice)
#    Bob: [3] (1 dice) ← CURRENT TURN
#
# CURRENT BID: 1 dice show 5 (by Alice)
#
# 📊 TOTAL DICE IN PLAY: 4
#
# 📜 RECENT HISTORY:
#    • Challenge: Bob vs Alice - Alice wins
#    • Alice bids 1 dice show 5
#    • Bob challenges Alice's bid
#    • Challenge: Bob vs Alice - Alice wins
#    • Alice bids 1 dice show 5
#
# Bob's turn
#
# 🤔 Bob is thinking...
# 💭 Bob's thoughts:
#    Okay, let's analyze this Liar's Dice situation.
#
# 1. My hand: I have one die showing a 3. The current bid is 1 die showing a 5. Given my hand, it's impossible for me to contribute to the bid, but I can't count out the possibility.
#
# 2. Opponent's Bidding: Alice has been successful twice in a row. Each time, her bids have been for a quantity of 1 die showing 5. This means she could have a 5, a 1, or she might be bluffing.
#
# 3. Odds: There are 4 dice in the game. The current bid is 1 die showing 5. The probability of at least one die showing a 5 (or a 1, which counts as a 5) is moderately high. It's probably higher than 50%.
#
# 4. Decision: I have one die. Given my hand, bidding higher is not a good idea. Challenging is risky because I don't have a strong reason to believe she's lying. Given Alice's pattern, and the number of dice, I think she's probably telling the truth, or the chances of her lying are close enough to 50/50 to justify a challenge. Let's challenge.
#
# 5. Action: Challenge
#
# 🤖 Bob decides: CHALLENGE
#
#                   🚨 CHALLENGE RESOLUTION 🚨
# Bob challenges Alice's bid:
# BID: 1 dice show 5
#
# COUNTING DICE SHOWING 5:
#    Alice: 1 natural 5s + 0 wilds = 1 total
#    Bob: 0 natural 5s + 0 wilds = 0 total
#
# FINAL COUNT: 1 dice show 5
# BID CLAIMED: 1 dice show 5
# ✅ BID WAS TRUE! Bob loses a die!
# Alice wins the challenge!
# Bob now has 0 dice
# Bob is eliminated! 💀
#
# 🎉 Alice WINS THE GAME! 🎉
#
# Game finished after 5 turns!
# Final game history:
#    1. Alice bids 2 dice show 5
#    2. Bob challenges Alice's bid
#    3. Challenge: Bob vs Alice - Alice wins
#    4. Alice bids 1 dice show 5
#    5. Bob challenges Alice's bid
#    6. Challenge: Bob vs Alice - Alice wins
#    7. Alice bids 1 dice show 5
#    8. Bob challenges Alice's bid
#    9. Challenge: Bob vs Alice - Alice wins
# ```

# %% [markdown]
# ## Setup

# %%
from decouple import Config, RepositoryEnv

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
import time
import re
import random
from typing import Dict, List, Optional

# %%
from liarsdice import LiarsDiceGame

# %%
config = Config(RepositoryEnv(".env"))

# %%
GOOGLE_API_KEY = config("GOOGLE_API_KEY")

# %% [markdown]
# ## Making a functional Liar's Dice game

# %% [markdown]
# A game orchestrator has already been implemented for you in `liarsdice.py`. The only missing part to start your first game of Liar's Dice is to implement `AIPlayer` below. Study the orchestrator to understand how the game is run before filling out the code below. Make any changes you want anywhere, as long as you can get it to work.

# %%
class AIPlayer:
    def __init__(self, name: str, llm):
        self.name = name
        self.llm = llm

        # The example shows how to store variable names in the prompt
        # Refer to self.system_chain.invoke()'s parameters for variables
        # TODO: Modify this!
        self.system_prompt = ChatPromptTemplate.from_template("""
            You are {player_name} playing Liar's Dice. Your goal is to win the game with the best strategy played.

            GAME RULES:
            1. Each player rolls hidden dice with faces from 1 to 6.
            2. The game is played in turns.
            3. On each turn, a player may either:
               - Make a higher bid (as per the bid hierarchy).
               - Make a challenge, that is, call the previous player's bluff.
            4. Bid hierarchy increases first by quantity, then by face value. Example:
               - 2 fives < 2 sixes < 3 ones < 3 twos < ... < 4 sixes.
            5. A new bid must be strictly higher than the previous bid.
            6. When "CHALLENGE" is called, all dice are rerevealed, and the total number of the face value in the last bid is counted.
               - If the bid is valid (at least that many dice), the caller loses one die.
               - If the bid is false, the bidder loses one die.
            7. All dice are rerolled after each "CHALLENGE".
            
            In each round, YOUR INPUT will include:
            - Your hidden dice
            - Current bid or challenge (or None if you're starting)
            - Game history
            - Total dice counts
            After receiving the input, think on the game and decide what is the next move. Output your reasoning and make your decision.

            DO NOT make random bids. Use reasoning based on your own dice and the total dice count.
            DO NOT assume knowledge of other players' dice. You may deduce over other player's dice, but they are merely your guesses.
            DO follow the output format exactly.
            NEVER break the rules.
            Stay focused and dedicated to your goals. Your consistent efforts will lead to outstanding achievements.
            Take pride in your work and give it your best.
            
            The game will start now. Please acknowledge this message with "OK".
        """)  # Hmmmm, does emotion prompting work?

        # TODO: Modify this!
        # Ensure that the output is either just "CHALLENGE"
        # or "BID <num of dice> <dice face value>"
        self.decision_prompt = ChatPromptTemplate.from_template("""
            There are total {total_dice} dice in the game now. Your private dice is {my_dice}.

            The current bid is: {current_bid}.

            Full game history:
            {game_history}

            Think through the game. Give your thoughts in detailed and end your output with the decision format specified above.
            
            Output your decision in a separate line. Your output must be one of the following:
            - To make a bid: "BID <num of dice> <dice face value>"
            - To challenge: "CHALLENGE"
            You can't call liar when there is not current bid.
            The final line should not contain leading or trailing spaces, or other characters than the format specified.
            The final line should start with BID or CHALLENGE without any markdown formatting.

            These are BAD decision examples:
            - Decision: BID 3 4
            - **CHALLENGE**
            - BID 2 dice show 6
            - bid two six
            - BID CHALLENGE
            - CHALLENGE 6 2
            - I choose to challenge.
            - **BID 1 5**
            - BID 4 6.
            Giving such outputs will disqualify you immediately.

            These are GOOD decision examples:
            - BID 3 4
            - CHALLENGE
            - BID 4 6
            - BID 2 1
        """)

        self.system_chain = self.system_prompt | self.llm | StrOutputParser()
        self.decision_chain = self.decision_prompt | self.llm | StrOutputParser()

        self._init_llm()

    def make_decision(
        self,
        my_dice: List[int],
        total_dice: int,
        current_bid: Optional[Dict],
        game_history: List[str],
    ) -> Dict:
        """
        Given information about the game, get LLMs to decide what to do next!
        """
        current_bid_str = (
            "None (you start)"
            if not current_bid
            else f"{current_bid['quantity']} dice show {current_bid['face_value']}"
        )
        history_str = (
            "\n".join(game_history[-10:]) if game_history else "Game just started"
        )

        try:
            # TODO: Modify this!
            output = self.decision_chain.invoke({
                "total_dice": total_dice,
                "my_dice": my_dice,
                "current_bid": current_bid_str,
                "game_history": history_str
            })
            print(f"[{self.name}] Player's thoughts: {output}")
    
            decision = self._parse_decision(output)
            return decision
        except Exception as e:
            print(f"[{self.name}] ❌ An error occured: {e}")
            return self._fallback_decision(current_bid)

    def _init_llm(self):
        """
        Feed system prompt to LLM.
        """
        output = self.system_chain.invoke({"player_name": self.name})
        print(f"[{self.name}] LLM initialized with system prompt. Response: {output}")

    def _parse_decision(self, response: str) -> Dict:
        """
        Parse the LLM's decision response.
                
        Valid return output examples:

        {"action": "challenge"}
        {"action": "bid", "quantity": 3, "face_value": 4}
        {"action": "bid", "quantity": 4, "face_value": 2}
        """
        # TODO: Modify this!
        decision = list(re.finditer(r"\bBID\s+(\d+)\s+(\d+)\b|\bCHALLENGE\b", response))
        if not decision:  # No matches
            raise RuntimeError("Fail to parse decision")
        decision = decision[-1]  # Take the last one if there are multiple matches
        
        if decision.group(0) == "CHALLENGE":
            return {"action": "challenge"}
        else:
            quantity, face_value = int(decision.group(1)), int(decision.group(2))
            return {"action": "bid", "quantity": quantity, "face_value": face_value}

    def _fallback_decision(self, current_bid: Optional[Dict]) -> Dict:
        """
        Intelligent fallback decision based on game state.
        This is implemented for you in advance.
        """
        if not current_bid:
            return {
                "action": "bid",
                "quantity": random.randint(1, 2),
                "face_value": random.randint(2, 6),
            }

        # More likely to challenge high bids
        bid_aggression = current_bid["quantity"] / 10.0  # Rough aggression metric
        challenge_probability = min(0.6, bid_aggression)

        if random.random() < challenge_probability:
            return {"action": "challenge"}
        else:
            # Make a reasonable increase
            if current_bid["face_value"] < 6:
                return {
                    "action": "bid",
                    "quantity": current_bid["quantity"],
                    "face_value": current_bid["face_value"] + 1,
                }
            else:
                return {
                    "action": "bid",
                    "quantity": current_bid["quantity"] + 1,
                    "face_value": 2,
                }

# %% [markdown]
# When you are done, try running a game of Liar's Dice below!

# %%
game = LiarsDiceGame()

# Setup game
players = [
    AIPlayer(
        name="Alice",
        llm=ChatGoogleGenerativeAI(
            temperature=0.8, model="gemini-2.0-flash-lite", api_key=GOOGLE_API_KEY
        ),
    ),
    AIPlayer(
        name="Bob",
        llm=ChatGoogleGenerativeAI(
            temperature=0.8, model="gemini-2.0-flash-lite", api_key=GOOGLE_API_KEY
        ),
    ),
]

# 2 players, 3 dice for fast resolution
game.setup_game(players, dice_per_player=3)

# Play game
turn_count = 0
max_turns = 25

while turn_count < max_turns:
    print(f"\n{'--- TURN ' + str(turn_count + 1) + ' ---':^60}")

    game_ended = not game.play_turn()
    if game_ended:
        break

    turn_count += 1

    # Pause for readability
    time.sleep(2)

if turn_count >= max_turns:
    print("\nGame ended due to turn limit")

print(f"\nGame finished after {turn_count} turns!")
print("Final game history:")
for i, action in enumerate(game.history, 1):
    print(f"   {i}. {action}")
# Out:
# [Alice] LLM initialized with system prompt. Response: OK
# [Bob] LLM initialized with system prompt. Response: OK
# LIAR'S DICE!
# Players: Alice, Bob
# Total dice: 6
#
# DICE (not visible to players):
# Alice: [1, 3, 5]
# Bob: [4, 5, 6]
#
#                        --- TURN 1 ---
#
# ============================================================
# ROUND 1 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1, 3, 5] (3 dice) ← CURRENT TURN
#    Bob: [4, 5, 6] (3 dice)
#
# CURRENT BID: None (round start)
#
# 📊 TOTAL DICE IN PLAY: 6
#
# Alice's turn
# [Alice] Player's thoughts: Okay, let's analyze this Liar's Dice situation.
#
# I have [1, 3, 5]. There are 6 total dice in the game. It's the first turn, so I can make any bid.
#
# Since my dice are [1, 3, 5], I don't have any pairs or runs to make a good initial bid. I will start with a bid that is somewhat conservative. I know I have one 1. Let's bid a single 1.
#
# BID 1 1
# ✅ Alice bids 1 dice show 1
#
#                        --- TURN 2 ---
#
# ============================================================
# ROUND 1 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1, 3, 5] (3 dice)
#    Bob: [4, 5, 6] (3 dice) ← CURRENT TURN
#
# CURRENT BID: 1 dice show 1 (by Alice)
#
# 📊 TOTAL DICE IN PLAY: 6
#
# 📜 RECENT HISTORY:
#    • Alice bids 1 dice show 1
#
# Bob's turn
# [Bob] Player's thoughts: Okay, let's analyze the situation.
#
# We have a total of 6 dice in the game. My private dice are 4, 5, and 6. The current bid is 1 dice showing 1. The previous bid was also 1 dice showing 1.
#
# Given the bid, I have a few options. I could believe there is at least one "1" showing, or I could believe there is not. Given that there is only one bid, and it's a low number, there's a reasonable chance to think the bid is correct. I could also raise the bid. Let's consider raising the bid.
#
# I could bid on more dice showing 1. However, the bid is already at 1 dice showing 1. Given that I have no 1s, and I know the last bidder also does not have any 1s, it is unlikely to be correct and I should raise the bid.
#
# I have a 4, 5, and 6, and the last bidder had no 1s. I can't bid on any 1s.
#
# Therefore, it is better to raise the bid.
#
# BID 2 1
# ✅ Bob bids 2 dice show 1
#
#                        --- TURN 3 ---
#
# ============================================================
# ROUND 1 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1, 3, 5] (3 dice) ← CURRENT TURN
#    Bob: [4, 5, 6] (3 dice)
#
# CURRENT BID: 2 dice show 1 (by Bob)
#
# 📊 TOTAL DICE IN PLAY: 6
#
# 📜 RECENT HISTORY:
#    • Alice bids 1 dice show 1
#    • Bob bids 2 dice show 1
#
# Alice's turn
# [Alice] Player's thoughts: Okay, let's analyze the situation.
#
# I have the dice [1, 3, 5]. The current bid is 2 dice showing 1. There are 6 dice in total in the game. The previous bids were 1 die showing 1 (Alice) and then 2 dice showing 1 (Bob).
#
# I need to decide whether to bid higher or challenge.
#
# I have one 1 in my hand. The bid is already 2 ones. Since there are 6 dice in total, there is a decent chance that there are at least 2 dice showing 1. I could try to bid 3 ones, but that seems a bit risky because I have only one 1. However, I could challenge and see if I am right.
#
# Given the limited information and the risk involved, it's probably best to challenge.
#
# CHALLENGE
#
#                   🚨 CHALLENGE RESOLUTION 🚨
# Alice challenges Bob's bid:
# BID: 2 dice show 1
#
# COUNTING DICE SHOWING 1:
#    Alice: 1 natural 1s + 1 wilds = 1 total
#    Bob: 0 natural 1s + 0 wilds = 0 total
#
# FINAL COUNT: 1 dice show 1
# BID CLAIMED: 2 dice show 1
# ❌ BID WAS FALSE! Bob loses a die!
# Alice wins the challenge!
# Bob now has 2 dice
#
# Rolling new dice for next round...
#    Alice: [1, 2, 3]
#    Bob: [5, 2]
#
# NEW ROUND 2! Alice starts with fresh dice
#
#                        --- TURN 4 ---
#
# ============================================================
# ROUND 2 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1, 2, 3] (3 dice) ← CURRENT TURN
#    Bob: [5, 2] (2 dice)
#
# CURRENT BID: None (round start)
#
# 📊 TOTAL DICE IN PLAY: 5
#
# 📜 RECENT HISTORY:
#    • Alice bids 1 dice show 1
#    • Bob bids 2 dice show 1
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Alice wins
#
# Alice's turn
# [Alice] Player's thoughts: Okay, let's analyze the situation. The game started, and Alice bid 1 die showing 1. Bob bid 2 dice showing 1, and Alice challenged, winning the challenge. This means Bob's bid was incorrect. Now I have 3 dice ([1, 2, 3]). There are 5 dice total in the game.
#
# Since I have the first move, and I know Alice won a challenge, I should consider starting conservatively. I could bid 1 die showing 1, but given the history of the game and my dice, I'll try to make a bid that would be hard to challenge. Since I have a 1, I will start with a bid of 1.
#
# BID 1 1
# ✅ Alice bids 1 dice show 1
#
#                        --- TURN 5 ---
#
# ============================================================
# ROUND 2 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1, 2, 3] (3 dice)
#    Bob: [5, 2] (2 dice) ← CURRENT TURN
#
# CURRENT BID: 1 dice show 1 (by Alice)
#
# 📊 TOTAL DICE IN PLAY: 5
#
# 📜 RECENT HISTORY:
#    • Alice bids 1 dice show 1
#    • Bob bids 2 dice show 1
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Alice wins
#    • Alice bids 1 dice show 1
#
# Bob's turn
# [Bob] Player's thoughts: Okay, let's analyze the situation.
#
# We have 5 dice in the game total. My private dice are [5, 2]. The current bid is 1 dice showing 1. The game history shows a sequence of bids and a challenge where Alice won, and now it is my turn.
#
# The previous history is relevant. Alice's previous bid of 1 dice show 1 was challenged and she won. This suggests a possible strategy of trying to force players to challenge with low bids.
# Now it is my turn. I have a 5 and a 2. The current bid is 1 dice showing 1.
#
# Given my dice, I can either:
#
# 1.  **Bid higher**: I could bid 2 dice showing 1. This is risky, since it's likely that the other players may not have ones.
# 2.  **Challenge**: I could challenge the bid. Given that the total number of dice is 5, and the previous bid was 1 dice showing 1, it's possible that there are not more 1s.
#
# I have a 5, so I know I have at least one die that has value 5. I could bid 2 dice showing 2, or 2 dice showing 5.
#
# Considering the game history and my dice, I think it's better to make a bid to see how other players will react.
#
# BID 2 2
# ✅ Bob bids 2 dice show 2
#
#                        --- TURN 6 ---
#
# ============================================================
# ROUND 2 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1, 2, 3] (3 dice) ← CURRENT TURN
#    Bob: [5, 2] (2 dice)
#
# CURRENT BID: 2 dice show 2 (by Bob)
#
# 📊 TOTAL DICE IN PLAY: 5
#
# 📜 RECENT HISTORY:
#    • Bob bids 2 dice show 1
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Alice wins
#    • Alice bids 1 dice show 1
#    • Bob bids 2 dice show 2
#
# Alice's turn
# [Alice] Player's thoughts: Okay, let's analyze the situation.
#
# We have 5 dice in total, and my private dice show [1, 2, 3]. The current bid is 2 dice showing 2. The game history shows that Alice and Bob have both made bids and been challenged. Alice won a challenge.
#
# Considering the current bid of 2 dice showing 2, and knowing my own dice, I know I have one die showing 2. There are 5 dice in total, so it's possible that the bid is accurate. However, it is very likely that the other players have at least one 2. I can either raise the bid or challenge. If I challenge, and there are less than 2 dice showing 2, I win. If I raise, I can bid 3 dice showing 2, but I only have one 2 myself. I can also bid on a different face value.
#
# Given that there are 5 dice total and I have one 2, I think it's a good idea to challenge.
#
# CHALLENGE
#
#                   🚨 CHALLENGE RESOLUTION 🚨
# Alice challenges Bob's bid:
# BID: 2 dice show 2
#
# COUNTING DICE SHOWING 2:
#    Alice: 1 natural 2s + 1 wilds = 2 total
#    Bob: 1 natural 2s + 0 wilds = 1 total
#
# FINAL COUNT: 3 dice show 2
# BID CLAIMED: 2 dice show 2
# ✅ BID WAS TRUE! Alice loses a die!
# Bob wins the challenge!
# Alice now has 2 dice
#
# Rolling new dice for next round...
#    Alice: [2, 4]
#    Bob: [3, 5]
#
# NEW ROUND 3! Bob starts with fresh dice
#
#                        --- TURN 7 ---
#
# ============================================================
# ROUND 3 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [2, 4] (2 dice)
#    Bob: [3, 5] (2 dice) ← CURRENT TURN
#
# CURRENT BID: None (round start)
#
# 📊 TOTAL DICE IN PLAY: 4
#
# 📜 RECENT HISTORY:
#    • Challenge: Alice vs Bob - Alice wins
#    • Alice bids 1 dice show 1
#    • Bob bids 2 dice show 2
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Bob wins
#
# Bob's turn
# [Bob] Player's thoughts: Okay, let's analyze the game and make a decision.
#
# We are starting a new round. We have two dice: 3 and 5. The game history shows a pattern. Alice and Bob have both bid and challenged, with each winning one challenge. The current bid is none (we start). The total number of dice in play is 4.
#
# My strategy here is to start conservatively. I'll start by bidding on a value I have. Since I have a 5, I'll bid one 5.
#
# BID 1 5
# ✅ Bob bids 1 dice show 5
#
#                        --- TURN 8 ---
#
# ============================================================
# ROUND 3 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [2, 4] (2 dice) ← CURRENT TURN
#    Bob: [3, 5] (2 dice)
#
# CURRENT BID: 1 dice show 5 (by Bob)
#
# 📊 TOTAL DICE IN PLAY: 4
#
# 📜 RECENT HISTORY:
#    • Alice bids 1 dice show 1
#    • Bob bids 2 dice show 2
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Bob wins
#    • Bob bids 1 dice show 5
#
# Alice's turn
# [Alice] Player's thoughts: Okay, let's analyze the game state and make a decision.
#
# We have two dice: 2 and 4. The current bid is 1 dice showing 5. The game history shows some interesting dynamics. Alice and Bob have been trading bids and challenges. There have been two challenges, one won by Alice and one by Bob. Bob just won a challenge with this current bid.
#
# We know that we have two dice, and there are currently 4 dice in the game. The bid is 1 dice showing 5. Given our dice [2, 4], we don't have a 5. Bidding higher faces is difficult, but we know the current bid is low. Given the bidding history and Bob winning the last challenge. I will challenge.
#
# CHALLENGE
#
#                   🚨 CHALLENGE RESOLUTION 🚨
# Alice challenges Bob's bid:
# BID: 1 dice show 5
#
# COUNTING DICE SHOWING 5:
#    Alice: 0 natural 5s + 0 wilds = 0 total
#    Bob: 1 natural 5s + 0 wilds = 1 total
#
# FINAL COUNT: 1 dice show 5
# BID CLAIMED: 1 dice show 5
# ✅ BID WAS TRUE! Alice loses a die!
# Bob wins the challenge!
# Alice now has 1 dice
#
# Rolling new dice for next round...
#    Alice: [1]
#    Bob: [4, 4]
#
# NEW ROUND 4! Bob starts with fresh dice
#
#                        --- TURN 9 ---
#
# ============================================================
# ROUND 4 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1] (1 dice)
#    Bob: [4, 4] (2 dice) ← CURRENT TURN
#
# CURRENT BID: None (round start)
#
# 📊 TOTAL DICE IN PLAY: 3
#
# 📜 RECENT HISTORY:
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Bob wins
#    • Bob bids 1 dice show 5
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Bob wins
#
# Bob's turn
# [Bob] Player's thoughts: Okay, let's analyze the game.
#
# Currently, there are 3 dice remaining in the game. My private dice are [4, 4]. The game history shows a pattern of bids and challenges. I see the following history:
# 1. Bob bids 2 dice show 1
# 2. Alice challenges Bob's bid
# 3. Challenge: Alice vs Bob - Alice wins
# 4. Alice bids 1 dice show 1
# 5. Bob bids 2 dice show 2
# 6. Alice challenges Bob's bid
# 7. Challenge: Alice vs Bob - Bob wins
# 8. Bob bids 1 dice show 5
# 9. Alice challenges Bob's bid
# 10. Challenge: Alice vs Bob - Bob wins
#
# The previous bids were 1 dice of 5. I see the pattern of people challenging, and if the bids are accurate they are winning. Since I have 2 dice that show 4, and the previous bid was 1 die of 5, I can assume a reasonable strategy is to bid on a number that I have. Therefore, I should bid 2 dice of 4.
#
# BID 2 4
# ✅ Bob bids 2 dice show 4
#
#                       --- TURN 10 ---
#
# ============================================================
# ROUND 4 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1] (1 dice) ← CURRENT TURN
#    Bob: [4, 4] (2 dice)
#
# CURRENT BID: 2 dice show 4 (by Bob)
#
# 📊 TOTAL DICE IN PLAY: 3
#
# 📜 RECENT HISTORY:
#    • Challenge: Alice vs Bob - Bob wins
#    • Bob bids 1 dice show 5
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Bob wins
#    • Bob bids 2 dice show 4
#
# Alice's turn
# [Alice] Player's thoughts: Okay, let's analyze the game.
#
# My private dice is [1]. There are 3 dice in the game. The current bid is 2 dice showing 4. The game history shows a series of challenges, indicating some level of risk-taking and bluffing. The previous bids were 1-1, 2-2, 1-5, and 2-4. I have a 1, so I have to consider the probabilities.
#
# Given my single die, I'm unlikely to have any 4s. So I should be cautious about bidding a higher number of 4s or challenging the current bid. The current bid is 2 dice showing 4.
#
# Since I have a 1, I could bid 1 die showing 1 or I could challenge. I think it's more risky to increase the number of 4s since I do not have any. Bidding 1 die showing 1 is a good option to avoid challenging.
#
# BID 1 1
# ❌ Invalid bid from Alice! Auto-correcting...
# 🔧 Alice bids 2 dice show 5 (auto-corrected)
#
#                       --- TURN 11 ---
#
# ============================================================
# ROUND 4 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1] (1 dice)
#    Bob: [4, 4] (2 dice) ← CURRENT TURN
#
# CURRENT BID: 2 dice show 5 (by Alice)
#
# 📊 TOTAL DICE IN PLAY: 3
#
# 📜 RECENT HISTORY:
#    • Bob bids 1 dice show 5
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Bob wins
#    • Bob bids 2 dice show 4
#    • Alice bids 2 dice show 5 (auto-corrected)
#
# Bob's turn
# [Bob] Player's thoughts: Okay, let's analyze the game.
#
# My dice are [4, 4]. There are 3 dice remaining in the game (including mine). The current bid is 2 dice showing 5. The game history shows that Bob has been winning the challenges, and Alice has been bidding aggressively.
#
# Given my dice, I have no dice showing 5. I have two 4s, so I can't bid on a 5. I can't challenge because the bid is possible (though perhaps unlikely given my dice).
#
# My options:
# 1.  Bid on a higher number of dice showing 5. This is risky because I have no 5s, and only 3 dice are left.
# 2.  Bid on a different face value. I could bid on 2 dice showing 4, but the previous bid was 2 dice showing 5, so it's not a good choice.
# 3.  I could bid 3 dice showing 6, but there is no chance to win with that bid.
#
# Considering the information, I should bid on 2 dice showing 6.
#
# BID 2 6
# ✅ Bob bids 2 dice show 6
#
#                       --- TURN 12 ---
#
# ============================================================
# ROUND 4 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [1] (1 dice) ← CURRENT TURN
#    Bob: [4, 4] (2 dice)
#
# CURRENT BID: 2 dice show 6 (by Bob)
#
# 📊 TOTAL DICE IN PLAY: 3
#
# 📜 RECENT HISTORY:
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Bob wins
#    • Bob bids 2 dice show 4
#    • Alice bids 2 dice show 5 (auto-corrected)
#    • Bob bids 2 dice show 6
#
# Alice's turn
# [Alice] Player's thoughts: Okay, let's analyze the game.
#
# I have one die showing a 1. There are three dice in total remaining in the game. The current bid is 2 dice showing 6.
#
# Looking at the history:
#
# *   Alice bid 1 die showing 1.
# *   Bob bid 2 dice showing 2 (This was the first challenge)
# *   Alice challenged Bob. Bob wins.
# *   Bob bid 1 die showing 5.
# *   Alice challenges Bob. Bob wins.
# *   Bob bid 2 dice showing 4.
# *   Alice bids 2 dice showing 5.
# *   Bob bids 2 dice showing 6.
#
# Given the current bid of "2 dice showing 6", and I only have 1 die, I don't have a good chance of bidding higher. I can't increase the quantity, because there are only 3 dice in total. If I challenge, there is a chance that the bid is not true. I have a low possibility of winning if I bid higher.
#
# Therefore, my best choice is to challenge.
#
# CHALLENGE
#
#                   🚨 CHALLENGE RESOLUTION 🚨
# Alice challenges Bob's bid:
# BID: 2 dice show 6
#
# COUNTING DICE SHOWING 6:
#    Alice: 0 natural 6s + 1 wilds = 1 total
#    Bob: 0 natural 6s + 0 wilds = 0 total
#
# FINAL COUNT: 1 dice show 6
# BID CLAIMED: 2 dice show 6
# ❌ BID WAS FALSE! Bob loses a die!
# Alice wins the challenge!
# Bob now has 1 dice
#
# Rolling new dice for next round...
#    Alice: [6]
#    Bob: [5]
#
# NEW ROUND 5! Alice starts with fresh dice
#
#                       --- TURN 13 ---
#
# ============================================================
# ROUND 5 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [6] (1 dice) ← CURRENT TURN
#    Bob: [5] (1 dice)
#
# CURRENT BID: None (round start)
#
# 📊 TOTAL DICE IN PLAY: 2
#
# 📜 RECENT HISTORY:
#    • Bob bids 2 dice show 4
#    • Alice bids 2 dice show 5 (auto-corrected)
#    • Bob bids 2 dice show 6
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Alice wins
#
# Alice's turn
# [Alice] Player's thoughts: Okay, let's analyze the game.
#
# I have one die showing a 6. There are two dice remaining in the game. The game history shows a mix of wins and losses, but Bob seems to be a somewhat strong player, having won most of the challenges. The last challenge resulted in Alice winning, meaning Bob's previous bid was incorrect.
#
# The current bid is "None," meaning it's my turn to start. Given that I only have one die, and the previous bids were from a range of 1 to 2 dice, I want to make an initial bid. I could start with a bid of 1 die showing a 6, but since the opponents have lost a die each, I'm trying to maximize my value. I can't bid 2 of a value, because I only have one die. So I'll bid 1 of the highest possible number given my current die value.
#
# BID 1 6
# ✅ Alice bids 1 dice show 6
#
#                       --- TURN 14 ---
#
# ============================================================
# ROUND 5 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [6] (1 dice)
#    Bob: [5] (1 dice) ← CURRENT TURN
#
# CURRENT BID: 1 dice show 6 (by Alice)
#
# 📊 TOTAL DICE IN PLAY: 2
#
# 📜 RECENT HISTORY:
#    • Alice bids 2 dice show 5 (auto-corrected)
#    • Bob bids 2 dice show 6
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Alice wins
#    • Alice bids 1 dice show 6
#
# Bob's turn
# [Bob] Player's thoughts: Okay, let's analyze the game.
#
# The current bid is 1 dice showing 6. My private dice is [5]. There are 2 dice left in the game.
#
# The history shows a pattern of bids and challenges. Specifically, I know that Alice won the last challenge.
#
# Given the bid of "1 dice show 6", I have a few options:
#
# 1.  **Challenge:** I could challenge, but the last time I challenged, I won. However, there's only one dice showing 6, and my private dice is 5. It is very likely that the opponent has 6.
# 2.  **Bid:** I can bid a higher number of dice with a 6 showing, or I can bid on a different face value. Since I have [5], it makes sense to bid on 5. Given that there are only 2 dice in play, it makes sense to try and bid on what I know.
#
# I will bid 1 die showing 5.
#
# BID 1 5
# ❌ Invalid bid from Bob! Auto-correcting...
# 🔧 Bob bids 2 dice show 2 (auto-corrected)
#
#                       --- TURN 15 ---
#
# ============================================================
# ROUND 5 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [6] (1 dice) ← CURRENT TURN
#    Bob: [5] (1 dice)
#
# CURRENT BID: 2 dice show 2 (by Bob)
#
# 📊 TOTAL DICE IN PLAY: 2
#
# 📜 RECENT HISTORY:
#    • Bob bids 2 dice show 6
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Alice wins
#    • Alice bids 1 dice show 6
#    • Bob bids 2 dice show 2 (auto-corrected)
#
# Alice's turn
# [Alice] Player's thoughts: Okay, let's analyze the game.
#
# My private dice is [6]. The current bid is 2 dice showing 2. My options are to either bid higher, or challenge.
#
# The history shows a lot of back and forth. Bob seems to be playing aggressively, and Alice seems to be challenging at appropriate times. In the previous round, Alice won the challenge, and now she is bidding with one 6. I am in a good situation as I have a 6 myself and I can increase the bid. I can bid 2 dice showing 6.
#
# BID 2 6
# ✅ Alice bids 2 dice show 6
#
#                       --- TURN 16 ---
#
# ============================================================
# ROUND 5 - GAME STATE
# ============================================================
# PLAYERS:
#    Alice: [6] (1 dice)
#    Bob: [5] (1 dice) ← CURRENT TURN
#
# CURRENT BID: 2 dice show 6 (by Alice)
#
# 📊 TOTAL DICE IN PLAY: 2
#
# 📜 RECENT HISTORY:
#    • Alice challenges Bob's bid
#    • Challenge: Alice vs Bob - Alice wins
#    • Alice bids 1 dice show 6
#    • Bob bids 2 dice show 2 (auto-corrected)
#    • Alice bids 2 dice show 6
#
# Bob's turn
# [Bob] Player's thoughts: Okay, let's analyze the game.
#
# Currently, there are 2 dice left in the game. My private dice is [5]. The current bid is 2 dice showing 6.
#
# The history shows:
# *   Alice and Bob are playing.
# *   Alice challenged Bob, lost.
# *   Bob bid 2x4.
# *   Alice bid 2x5.
# *   Bob bid 2x6.
# *   Alice challenged Bob, won.
# *   Alice bid 1x6.
# *   Bob bid 2x2.
# *   Alice bid 2x6.
#
# Given that my dice is a 5 and the current bid is 2x6, I can either raise the bid or challenge. Raising the bid with a 6 would be risky. Since I only have one die and it's a 5, it's unlikely I can make a successful bid and I should challenge.
#
# CHALLENGE
#
#                   🚨 CHALLENGE RESOLUTION 🚨
# Bob challenges Alice's bid:
# BID: 2 dice show 6
#
# COUNTING DICE SHOWING 6:
#    Alice: 1 natural 6s + 0 wilds = 1 total
#    Bob: 0 natural 6s + 0 wilds = 0 total
#
# FINAL COUNT: 1 dice show 6
# BID CLAIMED: 2 dice show 6
# ❌ BID WAS FALSE! Alice loses a die!
# Bob wins the challenge!
# Alice now has 0 dice
# Alice is eliminated! 💀
#
# 🎉 Bob WINS THE GAME! 🎉
#
# Game finished after 15 turns!
# Final game history:
#    1. Alice bids 1 dice show 1
#    2. Bob bids 2 dice show 1
#    3. Alice challenges Bob's bid
#    4. Challenge: Alice vs Bob - Alice wins
#    5. Alice bids 1 dice show 1
#    6. Bob bids 2 dice show 2
#    7. Alice challenges Bob's bid
#    8. Challenge: Alice vs Bob - Bob wins
#    9. Bob bids 1 dice show 5
#    10. Alice challenges Bob's bid
#    11. Challenge: Alice vs Bob - Bob wins
#    12. Bob bids 2 dice show 4
#    13. Alice bids 2 dice show 5 (auto-corrected)
#    14. Bob bids 2 dice show 6
#    15. Alice challenges Bob's bid
#    16. Challenge: Alice vs Bob - Alice wins
#    17. Alice bids 1 dice show 6
#    18. Bob bids 2 dice show 2 (auto-corrected)
#    19. Alice bids 2 dice show 6
#    20. Bob challenges Alice's bid
#    21. Challenge: Bob vs Alice - Bob wins
